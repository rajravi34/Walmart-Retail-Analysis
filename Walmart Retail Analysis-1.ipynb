# %%
import pandas as pd
from datetime import date
data = pd.read_csv("Walmart_Store_sales.csv")
data
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
new = data.groupby("Store")
result = new["Weekly_Sales"].sum()
result
# Out:
# Store
# 1     2.224028e+08
# 2     2.753824e+08
# 3     5.758674e+07
# 4     2.995440e+08
# 5     4.547569e+07
# 6     2.237561e+08
# 7     8.159828e+07
# 8     1.299512e+08
# 9     7.778922e+07
# 10    2.716177e+08
# 11    1.939628e+08
# 12    1.442872e+08
# 13    2.865177e+08
# 14    2.889999e+08
# 15    8.913368e+07
# 16    7.425243e+07
# 17    1.277821e+08
# 18    1.551147e+08
# 19    2.066349e+08
# 20    3.013978e+08
# 21    1.081179e+08
# 22    1.470756e+08
# 23    1.987506e+08
# 24    1.940160e+08
# 25    1.010612e+08
# 26    1.434164e+08
# 27    2.538559e+08
# 28    1.892637e+08
# 29    7.714155e+07
# 30    6.271689e+07
# 31    1.996139e+08
# 32    1.668192e+08
# 33    3.716022e+07
# 34    1.382498e+08
# 35    1.315207e+08
# 36    5.341221e+07
# 37    7.420274e+07
# 38    5.515963e+07
# 39    2.074455e+08
# 40    1.378703e+08
# 41    1.813419e+08
# 42    7.956575e+07
# 43    9.056544e+07
# 44    4.329309e+07
# 45    1.123953e+08
# Name: Weekly_Sales, dtype: float64

# %% [markdown]
# Store 20 has the highest number of sales

# %%
new = data.groupby("Store")
sd = new["Weekly_Sales"].std()
sd
# Out:
# Store
# 1     155980.767761
# 2     237683.694682
# 3      46319.631557
# 4     266201.442297
# 5      37737.965745
# 6     212525.855862
# 7     112585.469220
# 8     106280.829881
# 9      69028.666585
# 10    302262.062504
# 11    165833.887863
# 12    139166.871880
# 13    265506.995776
# 14    317569.949476
# 15    120538.652043
# 16     85769.680133
# 17    112162.936087
# 18    176641.510839
# 19    191722.638730
# 20    275900.562742
# 21    128752.812853
# 22    161251.350631
# 23    249788.038068
# 24    167745.677567
# 25    112976.788600
# 26    110431.288141
# 27    239930.135688
# 28    181758.967539
# 29     99120.136596
# 30     22809.665590
# 31    125855.942933
# 32    138017.252087
# 33     24132.927322
# 34    104630.164676
# 35    211243.457791
# 36     60725.173579
# 37     21837.461190
# 38     42768.169450
# 39    217466.454833
# 40    119002.112858
# 41    187907.162766
# 42     50262.925530
# 43     40598.413260
# 44     24762.832015
# 45    130168.526635
# ...

# %% [markdown]
# Store 14 has the highest standard deviation

# %%
new = data.groupby("Store")
mean = new["Weekly_Sales"].mean()
mean
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %%
coefficient = mean.max()/sd.max()
coefficient
# Out:
# 6.636890152329103

# %% [markdown]
# The coefficient of the maximum mean and maximum standard deviation is 6.636890152329103.

# %%
data["Date"] = pd.to_datetime(data["Date"])
Q3_from = pd.Timestamp(date(2012,7,1))
Q3_to = pd.Timestamp(date(2012,9,30))
Q3data=data[(data['Date'] > Q3_from) & (data['Date'] < Q3_to)]
Q3 = pd.DataFrame(Q3data.groupby('Store')['Weekly_Sales'].sum())
Q3.rename(columns={'Weekly_Sales': 'Q3_Weekly_Sales'})
# Out:
#        Q3_Weekly_Sales
# Store
# 1          18633209.98
# 2          22396867.61
# 3           4966495.93
# 4          25652119.35
# 5           3880621.88
# 6          18341221.11
# 7           7322393.92
# 8          10873860.34
# 9           6528239.56
# 10         21169356.45
# 11         16094363.07
# 12         11777508.50
# 13         24319994.35
# 14         20140430.40
# 15          6909374.37
# 16          6441311.11
# 17         11533998.38
# 18         12507521.72
# 19         16644341.31
# 20         24665938.11
# 21          8403507.99
# 22         11818544.33
# 23         17103654.36
# 24         16125999.86
# 25          8309440.44
# 26         12417575.35
# 27         20191238.11
# 28         15055659.67
# 29          6127862.07
# 30          5181974.44
# 31         16454328.46
# 32         14142164.84
# 33          3177072.43
# 34         11476258.98
# 35         10252122.68
# 36          3578123.58
# 37          6250524.08
# 38          5129297.64
# ...

# %%
non_holiday = data.groupby("Holiday_Flag")
count = non_holiday.get_group(0)
non_mean = count["Weekly_Sales"].mean()
non_mean
# Out:
# 1041256.3802088564

# %%
holiday = data.groupby("Holiday_Flag")
number = holiday.get_group(1)
number
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 31        1 2010-10-09    1507460.69             1        78.69       2.565
# 42        1 2010-11-26    1955624.11             1        64.52       2.735
# 47        1 2010-12-31    1367320.01             1        48.43       2.943
# 53        1 2011-11-02    1649614.93             1        36.39       3.022
# ...     ...        ...           ...           ...          ...         ...
# 6375     45 2011-09-09     746129.56             1        71.48       3.738
# 6386     45 2011-11-25    1170672.94             1        48.71       3.492
# 6391     45 2011-12-30     869403.63             1        37.79       3.389
# 6397     45 2012-10-02     803657.12             1        37.00       3.640
# 6427     45 2012-07-09     766512.66             1        75.70       3.911
#
#              CPI  Unemployment
# ...

# %%
bowl = number.groupby("Date")
Super_Bowl_10 = bowl.get_group("12-02-2010")["Weekly_Sales"].sum()
Super_Bowl_11 = bowl.get_group("11-02-2011")["Weekly_Sales"].sum()
Super_Bowl_12 = bowl.get_group("10-02-2012")["Weekly_Sales"].sum()
Labor_Day_10 = bowl.get_group("10-09-2010")["Weekly_Sales"].sum()
Labor_Day_11 = bowl.get_group("09-09-2011")["Weekly_Sales"].sum()
Labor_Day_12 = bowl.get_group("07-09-2012")["Weekly_Sales"].sum()
Thanksgiving_10 = bowl.get_group("26-11-2010")["Weekly_Sales"].sum()
Thanksgiving_11 = bowl.get_group("25-11-2011")["Weekly_Sales"].sum()
Christmas_10 = bowl.get_group("31-12-2010")["Weekly_Sales"].sum()
Christmas_11 = bowl.get_group("30-12-2011")["Weekly_Sales"].sum()

# %%
result = pd.DataFrame({"Super Bowl 2010":Super_Bowl_10,"Super Bowl 2011":Super_Bowl_11,"Super Bowl 2012":Super_Bowl_12,"Super Bowl 2013":0,"Labor Day 2010":Labor_Day_10,"Labor Day 2011":Labor_Day_11,"Labor_Day 2012":Labor_Day_12,"Labor Day 2013":0,"Thanksgiving 2010":Thanksgiving_10,"Thanksgiving 2011":Thanksgiving_11,"Thanksgiving 2012":0,"Thanksgiving 2013":0,"Christmas 2010":Christmas_10,"Christmas 2011":Christmas_11,"Christmas 2012":0,"Christmas 2013":0},index = [0])

# %%
result
# Out:
#    Super Bowl 2010  Super Bowl 2011  Super Bowl 2012  Super Bowl 2013  \
# 0      48336677.63      47336192.79      50009407.92                0
#
#    Labor Day 2010  Labor Day 2011  Labor_Day 2012  Labor Day 2013  \
# 0     45634397.84     46763227.53     48330059.31               0
#
#    Thanksgiving 2010  Thanksgiving 2011  Thanksgiving 2012  Thanksgiving 2013  \
# 0        65821003.24        66593605.26                  0                  0
#
#    Christmas 2010  Christmas 2011  Christmas 2012  Christmas 2013
# 0      40432519.0     46042461.04               0               0

# %%
result > non_mean
# Out:
#    Super Bowl 2010  Super Bowl 2011  Super Bowl 2012  Super Bowl 2013  \
# 0             True             True             True            False
#
#    Labor Day 2010  Labor Day 2011  Labor_Day 2012  Labor Day 2013  \
# 0            True            True            True           False
#
#    Thanksgiving 2010  Thanksgiving 2011  Thanksgiving 2012  Thanksgiving 2013  \
# 0               True               True              False              False
#
#    Christmas 2010  Christmas 2011  Christmas 2012  Christmas 2013
# 0            True            True           False           False

# %% [markdown]
# The holidays that had less sales than the mean sales of the non-holidays were Super Bowl 2013 ,Labor Day 2013,   Thanksgiving 2012, Thanksgiving 2013, Christmas 2012, and Christmas 2013.

# %%
data["Date"] = pd.to_datetime(data["Date"])
Jan_2010_to = pd.Timestamp(date(2010,1,1))
Jan_2010_from = pd.Timestamp(date(2010,1,31))
Jan_2011_to = pd.Timestamp(date(2011,1,1))
Jan_2011_from = pd.Timestamp(date(2011,1,31))
Jan_2012_to = pd.Timestamp(date(2012,1,1))
Jan_2012_from = pd.Timestamp(date(2012,1,31))
Feb_2010_to = pd.Timestamp(date(2010,2,1))
Feb_2010_from = pd.Timestamp(date(2010,2,28))
Feb_2011_to = pd.Timestamp(date(2011,2,1))
Feb_2011_from = pd.Timestamp(date(2011,2,28))
Feb_2012_to = pd.Timestamp(date(2012,2,1))
Feb_2012_from = pd.Timestamp(date(2012,2,29))
Mar_2010_to = pd.Timestamp(date(2010,3,1))
Mar_2010_from = pd.Timestamp(date(2010,3,31))
Mar_2011_to = pd.Timestamp(date(2011,3,1))
Mar_2011_from = pd.Timestamp(date(2011,3,31))
Mar_2012_to = pd.Timestamp(date(2012,3,1))
Mar_2012_from = pd.Timestamp(date(2012,3,31))
Apr_2010_to = pd.Timestamp(date(2010,4,1))
Apr_2010_from = pd.Timestamp(date(2010,4,30))
Apr_2011_to = pd.Timestamp(date(2011,4,1))
Apr_2011_from = pd.Timestamp(date(2011,4,30))
Apr_2012_to = pd.Timestamp(date(2012,4,1))
Apr_2012_from = pd.Timestamp(date(2012,4,30))
May_2010_to = pd.Timestamp(date(2010,5,1))
May_2010_from = pd.Timestamp(date(2010,5,31))
May_2011_to = pd.Timestamp(date(2011,5,1))
May_2011_from = pd.Timestamp(date(2011,5,31))

# %%
May_2012_to = pd.Timestamp(date(2012,5,1))
May_2012_from = pd.Timestamp(date(2012,5,31))
Jun_2010_to = pd.Timestamp(date(2010,6,1))
Jun_2010_from = pd.Timestamp(date(2010,6,30))
Jun_2011_to = pd.Timestamp(date(2011,6,1))
Jun_2011_from = pd.Timestamp(date(2011,6,30))
Jun_2012_to = pd.Timestamp(date(2012,6,1))
Jun_2012_from = pd.Timestamp(date(2012,6,30))
Jul_2010_to = pd.Timestamp(date(2010,7,1))
Jul_2010_from = pd.Timestamp(date(2010,7,31))
Jul_2011_to = pd.Timestamp(date(2011,7,1))
Jul_2011_from = pd.Timestamp(date(2011,7,31))
Jul_2012_to = pd.Timestamp(date(2012,7,1))
Jul_2012_from = pd.Timestamp(date(2012,7,31))
Aug_2010_to = pd.Timestamp(date(2010,8,1))
Aug_2010_from = pd.Timestamp(date(2010,8,31))
Aug_2011_to = pd.Timestamp(date(2011,8,1))
Aug_2011_from = pd.Timestamp(date(2011,8,31))
Aug_2012_to = pd.Timestamp(date(2012,8,1))
Aug_2012_from = pd.Timestamp(date(2012,8,31))
Sept_2010_to = pd.Timestamp(date(2010,9,1))
Sept_2010_from = pd.Timestamp(date(2010,9,30))
Sept_2011_to = pd.Timestamp(date(2011,9,1))
Sept_2011_from = pd.Timestamp(date(2011,9,30))
Sept_2012_to = pd.Timestamp(date(2012,9,1))
Sept_2012_from = pd.Timestamp(date(2012,9,30))
Oct_2010_to = pd.Timestamp(date(2010,10,1))
Oct_2010_from = pd.Timestamp(date(2010,10,31))
Oct_2011_to = pd.Timestamp(date(2011,10,1))
Oct_2011_from = pd.Timestamp(date(2011,10,31))
Oct_2012_to = pd.Timestamp(date(2012,10,1))
Oct_2012_from = pd.Timestamp(date(2012,10,31))
Nov_2010_to = pd.Timestamp(date(2010,11,1))
Nov_2010_from = pd.Timestamp(date(2010,11,30))
Nov_2011_to = pd.Timestamp(date(2011,11,1))
Nov_2011_from = pd.Timestamp(date(2011,11,30))
Nov_2012_to = pd.Timestamp(date(2012,11,1))
Nov_2012_from = pd.Timestamp(date(2012,11,30))
Dec_2010_to = pd.Timestamp(date(2010,12,1))
Dec_2010_from = pd.Timestamp(date(2010,12,31))
Dec_2011_to = pd.Timestamp(date(2011,12,1))
Dec_2011_from = pd.Timestamp(date(2011,12,31))
Dec_2012_to = pd.Timestamp(date(2012,12,1))
Dec_2012_from = pd.Timestamp(date(2012,12,31))

# %%
Jan_2010 = data[(data['Date'] > Jan_2010_to) & (data['Date'] < Jan_2010_from)]
Feb_2010 = data[(data["Date"] > Feb_2010_to) & (data["Date"] < Feb_2010_from)]
Mar_2010 = data[(data["Date"] > Mar_2010_to) & (data["Date"] < Mar_2010_from)]
Apr_2010 = data[(data["Date"] > Apr_2010_to) & (data["Date"] < Apr_2010_from)]
May_2010 = data[(data["Date"] > May_2010_to) & (data["Date"] < May_2010_from)]
Jun_2010 = data[(data["Date"] > Jun_2010_to) & (data["Date"] < Jun_2010_from)]
Jul_2010 = data[(data["Date"] > Jul_2010_to) & (data["Date"] < Jul_2010_from)]
Aug_2010 = data[(data["Date"] > Aug_2010_to) & (data["Date"] < Aug_2010_from)]
Sept_2010=data[(data["Date"] > Sept_2010_to) & (data["Date"] < Sept_2010_from)]
Oct_2010 = data[(data["Date"] > Oct_2010_to) & (data["Date"] < Oct_2010_from)]
Nov_2010 = data[(data["Date"] > Nov_2010_to) & (data["Date"] < Nov_2010_from)]
Dec_2010 = data[(data["Date"] > Dec_2010_to) & (data["Date"] < Dec_2010_from)]

# %%
Jan_2010_sales = Jan_2010["Weekly_Sales"].sum()
Feb_2010_sales = Feb_2010["Weekly_Sales"].sum()
Mar_2010_sales = Mar_2010["Weekly_Sales"].sum()
Apr_2010_sales = Apr_2010["Weekly_Sales"].sum()
May_2010_sales = May_2010["Weekly_Sales"].sum()
Jun_2010_sales = Jun_2010["Weekly_Sales"].sum()
Jul_2010_sales = Jul_2010["Weekly_Sales"].sum()
Aug_2010_sales = Aug_2010["Weekly_Sales"].sum()
Sept_2010_sales = Sept_2010["Weekly_Sales"].sum()
Oct_2010_sales = Oct_2010["Weekly_Sales"].sum()
Nov_2010_sales = Nov_2010["Weekly_Sales"].sum()
Dec_2010_sales = Dec_2010["Weekly_Sales"].sum()

# %%
Jan_2011 = data[(data['Date'] > Jan_2011_to) & (data['Date'] < Jan_2011_from)]
Feb_2011 = data[(data["Date"] > Feb_2011_to) & (data["Date"] < Feb_2011_from)]
Mar_2011 = data[(data["Date"] > Mar_2011_to) & (data["Date"] < Mar_2011_from)]
Apr_2011 = data[(data["Date"] > Apr_2011_to) & (data["Date"] < Apr_2011_from)]
May_2011 = data[(data["Date"] > May_2011_to) & (data["Date"] < May_2011_from)]
Jun_2011 = data[(data["Date"] > Jun_2011_to) & (data["Date"] < Jun_2011_from)]
Jul_2011 = data[(data["Date"] > Jul_2011_to) & (data["Date"] < Jul_2011_from)]
Aug_2011 = data[(data["Date"] > Aug_2011_to) & (data["Date"] < Aug_2011_from)]
Sept_2011=data[(data["Date"] > Sept_2011_to) & (data["Date"] < Sept_2011_from)]
Oct_2011 = data[(data["Date"] > Oct_2011_to) & (data["Date"] < Oct_2011_from)]
Nov_2011 = data[(data["Date"] > Nov_2011_to) & (data["Date"] < Nov_2011_from)]
Dec_2011 = data[(data["Date"] > Dec_2011_to) & (data["Date"] < Dec_2011_from)]

# %%
Jan_2011_sales = Jan_2011["Weekly_Sales"].sum()
Feb_2011_sales = Feb_2011["Weekly_Sales"].sum()
Mar_2011_sales = Mar_2011["Weekly_Sales"].sum()
Apr_2011_sales = Apr_2011["Weekly_Sales"].sum()
May_2011_sales = May_2011["Weekly_Sales"].sum()
Jun_2011_sales = Jun_2011["Weekly_Sales"].sum()
Jul_2011_sales = Jul_2011["Weekly_Sales"].sum()
Aug_2011_sales = Aug_2011["Weekly_Sales"].sum()
Sept_2011_sales = Sept_2011["Weekly_Sales"].sum()
Oct_2011_sales = Oct_2011["Weekly_Sales"].sum()
Nov_2011_sales = Nov_2011["Weekly_Sales"].sum()
Dec_2011_sales = Dec_2011["Weekly_Sales"].sum()

# %%
Jan_2012 = data[(data['Date'] > Jan_2012_to) & (data['Date'] < Jan_2012_from)]
Feb_2012 = data[(data["Date"] > Feb_2012_to) & (data["Date"] < Feb_2012_from)]
Mar_2012 = data[(data["Date"] > Mar_2012_to) & (data["Date"] < Mar_2012_from)]
Apr_2012 = data[(data["Date"] > Apr_2012_to) & (data["Date"] < Apr_2012_from)]
May_2012 = data[(data["Date"] > May_2012_to) & (data["Date"] < May_2012_from)]
Jun_2012 = data[(data["Date"] > Jun_2012_to) & (data["Date"] < Jun_2012_from)]
Jul_2012 = data[(data["Date"] > Jul_2012_to) & (data["Date"] < Jul_2012_from)]
Aug_2012 = data[(data["Date"] > Aug_2012_to) & (data["Date"] < Aug_2012_from)]
Sept_2012=data[(data["Date"] > Sept_2012_to) & (data["Date"] < Sept_2012_from)]
Oct_2012 = data[(data["Date"] > Oct_2012_to) & (data["Date"] < Oct_2012_from)]
Nov_2012 = data[(data["Date"] > Nov_2012_to) & (data["Date"] < Nov_2012_from)]
Dec_2012 = data[(data["Date"] > Dec_2012_to) & (data["Date"] < Dec_2012_from)]

# %%
Jan_2012_sales = Jan_2012["Weekly_Sales"].sum()
Feb_2012_sales = Feb_2012["Weekly_Sales"].sum()
Mar_2012_sales = Mar_2012["Weekly_Sales"].sum()
Apr_2012_sales = Apr_2012["Weekly_Sales"].sum()
May_2012_sales = May_2012["Weekly_Sales"].sum()
Jun_2012_sales = Jun_2012["Weekly_Sales"].sum()
Jul_2012_sales = Jul_2012["Weekly_Sales"].sum()
Aug_2012_sales = Aug_2012["Weekly_Sales"].sum()
Sept_2012_sales = Sept_2012["Weekly_Sales"].sum()
Oct_2012_sales = Oct_2012["Weekly_Sales"].sum()
Nov_2012_sales = Nov_2012["Weekly_Sales"].sum()
Dec_2012_sales = Dec_2012["Weekly_Sales"].sum()

# %%
import matplotlib.pyplot as plt
Walmart_2010 = {"Jan":Jan_2010_sales,"Feb":Feb_2010_sales,"Mar":Mar_2010_sales,"Apr":Apr_2010_sales,"May":May_2010_sales,"Jun":Jun_2010_sales,"Jul":Jul_2010_sales,"Aug":Aug_2010_sales, "Sept":Sept_2010_sales, "Oct":Oct_2010_sales, "Nov":Nov_2010_sales, "Dec":Dec_2010_sales}
month = list(Walmart_2010.keys())
value = list(Walmart_2010.values())
fig = plt.figure(figsize=(10,5))
plt.bar(month,value,color="blue",width=0.5)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("2010 Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
Walmart_2011 = {"Jan":Jan_2011_sales,"Feb":Feb_2011_sales,"Mar":Mar_2011_sales,"Apr":Apr_2011_sales,"May":May_2011_sales,"Jun":Jun_2011_sales,"Jul":Jul_2011_sales,"Aug":Aug_2011_sales, "Sept":Sept_2011_sales, "Oct":Oct_2011_sales, "Nov":Nov_2011_sales, "Dec":Dec_2011_sales}
month = list(Walmart_2011.keys())
value = list(Walmart_2011.values())
fig = plt.figure(figsize=(10,5))
plt.bar(month,value,color="red",width=0.5)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("2011 Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
Walmart_2012 = {"Jan":Jan_2012_sales,"Feb":Feb_2012_sales,"Mar":Mar_2012_sales,"Apr":Apr_2012_sales,"May":May_2012_sales,"Jun":Jun_2012_sales,"Jul":Jul_2012_sales,"Aug":Aug_2012_sales, "Sept":Sept_2012_sales, "Oct":Oct_2012_sales, "Nov":Nov_2012_sales, "Dec":Dec_2012_sales}
month = list(Walmart_2012.keys())
value = list(Walmart_2012.values())
fig = plt.figure(figsize=(10,5))
plt.bar(month,value,color="green",width=0.5)
plt.xlabel("Month")
plt.ylabel("Sales")
plt.title("2012 Sales")
plt.show()

# %%
data["Date"] = pd.to_datetime(data["Date"])
semester_one_from = pd.Timestamp(date(2010,1,1))
semester_one_to = pd.Timestamp(date(2010,6,30))
semester_two_from = pd.Timestamp(date(2010,7,1))
semester_two_to = pd.Timestamp(date(2010,12,31))
semester_one_sales = data[(data["Date"] > semester_one_from) & (data["Date"] < semester_one_to)]
semester_two_sales = data[(data["Date"] > semester_two_from) & (data["Date"] < semester_two_to)]
semester_one_2010 = semester_one_sales["Weekly_Sales"].sum()
semester_two_2010 = semester_two_sales["Weekly_Sales"].sum()

# %%
import matplotlib.pyplot as plt
semester = {"First Semester(Jan-Jun)":semester_one_2010,"Second Semester(Jul-Dec)":semester_two_2010}
month = list(semester.keys())
value = list(semester.values())
fig = plt.figure(figsize=(7,4))
plt.bar(month,value,color="purple",width=0.5)
plt.xlabel("Semester")
plt.ylabel("Number of Sales")
plt.title("2010 Semester Sales")
plt.show()

# %%
data["Date"] = pd.to_datetime(data["Date"])
semester_one_from_11 = pd.Timestamp(date(2011,1,1))
semester_one_to_11 = pd.Timestamp(date(2011,6,30))
semester_two_from_11 = pd.Timestamp(date(2011,7,1))
semester_two_to_11 = pd.Timestamp(date(2011,12,31))
semester_one_sales_11 = data[(data["Date"] > semester_one_from_11) & (data["Date"] < semester_one_to_11)]
semester_two_sales_11 = data[(data["Date"] > semester_two_from_11) & (data["Date"] < semester_two_to_11)]
semester_one_2011 = semester_one_sales_11["Weekly_Sales"].sum()
semester_two_2011 = semester_two_sales_11["Weekly_Sales"].sum()

# %%
import matplotlib.pyplot as plt
semester = {"First Semester(Jan-Jun)":semester_one_2011,"Second Semester(Jul-Dec)":semester_two_2011}
month = list(semester.keys())
value = list(semester.values())
fig = plt.figure(figsize=(10,5))
plt.bar(month,value,color="black",width=0.5)
plt.xlabel("Semester")
plt.ylabel("Number of Sales")
plt.title("2011 Semester Sales")
plt.show()

# %%
data["Date"] = pd.to_datetime(data["Date"])
semester_one_from_12 = pd.Timestamp(date(2012,1,1))
semester_one_to_12 = pd.Timestamp(date(2012,6,30))
semester_two_from_12 = pd.Timestamp(date(2012,7,1))
semester_two_to_12 = pd.Timestamp(date(2012,12,31))
semester_one_sales_12 = data[(data["Date"] > semester_one_from_12) & (data["Date"] < semester_one_to_12)]
semester_two_sales_12 = data[(data["Date"] > semester_two_from_12) & (data["Date"] < semester_two_to_12)]
semester_one_2012 = semester_one_sales_12["Weekly_Sales"].sum()
semester_two_2012 = semester_two_sales_12["Weekly_Sales"].sum()

# %%
import matplotlib.pyplot as plt
semester = {"First Semester(Jan-Jun)":semester_one_2012,"Second Semester(Jul-Dec)":semester_two_2012}
month = list(semester.keys())
value = list(semester.values())
fig = plt.figure(figsize=(10,5))
plt.bar(month,value,color="brown",width=0.5)
plt.xlabel("Semester")
plt.ylabel("Number of Sales")
plt.title("2012 Semester Sales")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
linereg = LinearRegression()
x_feature = data[["Holiday_Flag","Temperature","Fuel_Price","CPI","Unemployment"]]
y_target = data[["Weekly_Sales"]]
x_train,x_test,y_train,y_test = train_test_split(x_feature,y_target)
linereg.fit(x_feature,y_target)
linereg.fit(x_train,y_train)
y_pred = linereg.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.012013733518018932
